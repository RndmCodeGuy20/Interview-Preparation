# %% [markdown]
# # Harsh Zanwar
# ## CSE - AIML
# ## Comprehensive Viva Test - 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
data = pd.read_csv('data.csv')

data.head()
# Out:
#    month_number   facecream   facewash   toothpaste   bathingsoap   shampoo  \
# 0             1        2500       1500         5200          9200      1200
# 1             2        2630       1200         5100          6100      2100
# 2             3        2140       1340         4550          9550      3550
# 3             4        3400       1130         5870          8870      1870
# 4             5        3600       1740         4560          7760      1560
#
#     moisturizer   total_profit   total_units
# 0          1500         211000         21100
# 1          1200         183300         18330
# 2          1340         224700         22470
# 3          1130         222700         22270
# 4          1740         209600         20960

# %%
data.describe()
# Out:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo   moisturizer   total_profit   total_units
# count    12.000000     12.000000      12.000000      12.00000
# mean   2117.500000   1542.916667  260275.000000   26027.50000
# std     617.724931    316.733745   70143.659404    7014.36594
# min    1200.000000   1120.000000  183300.000000   18330.00000
# ...

# %%
plt.figure(figsize=(10, 10))

plt.hist(data[" total_profit"], bins=20, color='yellow')

plt.show()

# %%
plt.figure(figsize=(10, 10))

plt.pie(data.iloc[1, 1:-2], autopct='%1.1f%%')
plt.legend(data.columns[1:-2])

plt.show()

# %%
data.iloc[1, 1:]
# Out:
#  facecream         2630
#  facewash          1200
#  toothpaste        5100
#  bathingsoap       6100
#  shampoo           2100
#  moisturizer       1200
#  total_profit    183300
#  total_units      18330
# Name: 1, dtype: int64

# %%
plt.figure(figsize=(10, 10))

plt.plot(data[" bathingsoap"], color='red', label='bathing soap sales data')

plt.show()

# %%
plt.figure(figsize=(10, 10))

plt.plot([], [], color='m', label='face Cream', linewidth=5)
plt.plot([], [], color='c', label='Face wash', linewidth=5)
plt.plot([], [], color='r', label='Tooth paste', linewidth=5)
plt.plot([], [], color='k', label='Bathing soap', linewidth=5)
plt.plot([], [], color='g', label='Shampoo', linewidth=5)
plt.plot([], [], color='y', label='Moisturizer', linewidth=5)
plt.stackplot(data["month_number"], data[" facecream"], data[" facewash"], data[" toothpaste"], data[" bathingsoap"],
              data[" shampoo"],
              data[" moisturizer"],
              )
plt.show()
